# %% [markdown]
# ## Task 2 – Intermediate
# ### 1. Web Scraper

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://books.toscrape.com/"

response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")

    books = soup.find_all("article", class_="product_pod")

    data = []

    for book in books:
        title = book.h3.a["title"]
        price = book.find("p", class_="price_color").text
        availability = book.find("p", class_="instock availability").text.strip()

        data.append({
            "Title": title,
            "Price": price,
            "Availability": availability
        })

    df = pd.DataFrame(data)

    print(df)

    df.to_csv("scraped_books.csv", index=False)

    print("\nData successfully saved as scraped_books.csv")

else:
    print("Failed to access the website")
# Out:
#                                                 Title    Price Availability
# 0                                A Light in the Attic  Â£51.77     In stock
# 1                                  Tipping the Velvet  Â£53.74     In stock
# 2                                          Soumission  Â£50.10     In stock
# 3                                       Sharp Objects  Â£47.82     In stock
# 4               Sapiens: A Brief History of Humankind  Â£54.23     In stock
# 5                                     The Requiem Red  Â£22.65     In stock
# 6   The Dirty Little Secrets of Getting Your Dream...  Â£33.34     In stock
# 7   The Coming Woman: A Novel Based on the Life of...  Â£17.93     In stock
# 8   The Boys in the Boat: Nine Americans and Their...  Â£22.60     In stock
# 9                                     The Black Maria  Â£52.15     In stock
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  Â£13.99     In stock
# ...

# %% [markdown]
# ### Output
# The web scraper successfully extracted book titles, prices, and availability from the website and saved the data in a CSV file named scraped_books.csv.

# %% [markdown]
# ### 2. Hangman Game

# %%
import random

words = ["python", "java", "computer", "laptop", "coding"]

word = random.choice(words)

guessed = []
chances = 6

print("Welcome to Hangman Game")

while chances > 0:
    display = ""

    for letter in word:
        if letter in guessed:
            display = display + letter
        else:
            display = display + "_"

    print("\nWord:", display)

    if "_" not in display:
        print("You Won!")
        break

    guess = input("Enter a letter: ")

    if guess in guessed:
        print("You already entered this letter")
        continue

    guessed.append(guess)

    if guess in word:
        print("Correct!")
    else:
        chances = chances - 1
        print("Wrong!")
        print("Chances left:", chances)

if "_" in display:
    print("\nGame Over!")
    print("The word was:", word)
# Out:
# Welcome to Hangman Game
#
# Word: ______
# Enter a letter: p
# Correct!
#
# Word: __p__p
# Enter a letter: y
# Wrong!
# Chances left: 5
#
# Word: __p__p
